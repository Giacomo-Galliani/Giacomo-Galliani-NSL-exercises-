# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

z1 =np.loadtxt("pofv1.dat")
z2 =np.loadtxt("pofv2.dat")
z3 =np.loadtxt("pofv5.dat")
z4 =np.loadtxt("pofv10.dat")
z5 =np.loadtxt("pofv20.dat")

z5.reshape(-1,2)
x1 = z5[:, 0]
y1 = z5[:, 1]

plt.plot(x1, y1)
plt.grid(True)
plt.show()
