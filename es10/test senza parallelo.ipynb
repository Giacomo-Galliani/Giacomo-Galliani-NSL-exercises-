# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

z = np.loadtxt("sorted_cities.dat")
z.reshape(-1,2)

x =z[:,0]
y =z[:,1]

plt.plot(x,y)
plt.grid(True)
plt.show()
