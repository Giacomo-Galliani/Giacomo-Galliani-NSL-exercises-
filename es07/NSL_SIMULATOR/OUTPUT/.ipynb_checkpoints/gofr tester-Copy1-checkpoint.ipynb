# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

z =np.loadtxt("gofrblocks.dat")
z.reshape(-1,3)
x = z[:,0]
y = z[:,2]

plt.plot(x[1900:], y[1900:])
plt.grid(True)
plt.show()

# %%
z =np.loadtxt("gofr.dat")
z.reshape(-1,3)
x = z[:,0]
y = z[:,1]
err = z[:,2]

plt.errorbar(x, y, yerr = err)
plt.grid(True)
plt.show()
